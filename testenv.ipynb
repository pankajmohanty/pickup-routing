# %%
from Warehouse import Warehouse

# %%
warehouse = Warehouse(7, 2)
warehouse.show()
# Out:
# [1, 10, 'left']
# [1, 10, 'left']

# %%
from utils import FloydWarshel

floyd = FloydWarshel()

# %%
V = 4
INF = 100**7
graph = [ [ 0, 3, INF, 7 ],[ 8, 0, 2, INF ],[ 5, INF, 0, 1 ],[ 2, INF, INF, 0 ] ]
graph
# Out:
# [[0, 3, 100000000000000, 7],
#  [8, 0, 2, 100000000000000],
#  [5, 100000000000000, 0, 1],
#  [2, 100000000000000, 100000000000000, 0]]

# %%
floyd.get_res(V, graph, 1, 3)
# Out:
# Shortest path from 1 to 3: 1 -> 2 -> 3
